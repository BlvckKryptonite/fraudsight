# %%
import pandas as pd

df = pd.read_csv("../data/cleaned_transactions.csv")
df.shape

# %%
# Representative sample (5k rows)
df_sample = df.sample(n=5000, random_state=42)
df_sample.shape

# %%
df_sample.to_csv(
    "../data/cleaned_transactions_sample.csv",
    index=False
)
